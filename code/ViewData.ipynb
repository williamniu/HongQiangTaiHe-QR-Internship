# %%
# 查看pkl文件具体内容
import pickle

file_path = rf'/home/user45/NZH/model_test/GHMM--label1/ALL-validperiod1/20230103.pkl'
with open(file_path,'rb') as file:
    data = pickle.load(file)
print(data)
# Out:
#            value
# Code
# 000001 -0.933308
# 000002 -0.933308
# 000006 -0.933308
# 000007  1.358039
# 000008 -0.933308
# ...          ...
# 301388 -0.933308
# 301389 -0.933308
# 301391 -0.933308
# 301396 -0.933308
# 301398 -0.933308
#
# [2643 rows x 1 columns]

# %%
import pandas as pd
file_path = rf'/project/model_share/share_1/factor_data/fac20240819/2023q1_num-1266.fea'
df = pd.read_feather(file_path)
df
# Out:
#              date    Code   fac0001   fac0002   fac0003   fac0004   fac0005  \
# 0        20210104  000001  0.103297  0.508136 -0.276862 -4.331658  0.261553
# 1        20210104  000002  0.041108  0.692095 -0.148505 -3.625367  0.389545
# 2        20210104  000004  0.061697  0.900875 -0.046951 -1.091614  0.458014
# 3        20210104  000005  0.000000  0.932106 -0.026149  0.495133  0.558257
# 4        20210104  000006  0.032552  0.958341 -0.025876 -1.673883  0.331534
# ...           ...     ...       ...       ...       ...       ...       ...
# 2156697  20240628  301587  0.016038  0.879547 -0.072777 -2.454141  0.322910
# 2156698  20240628  301588  0.169935  0.920414 -0.042225 -2.017679  0.305934
# 2156699  20240628  301589  0.207143  0.753724 -0.000923  0.686237  0.852596
# 2156700  20240628  301591  0.317291  0.665515 -0.073279 -0.037634  0.570078
# 2156701  20240628  301596  0.180672  0.612885 -0.127593 -0.940101  0.443738
#
# ...

# %%
file_path = rf'/project/model_share/share_1/label_data/label1.fea'
df = pd.read_feather(file_path)
df
# Out:
#         index    000001    000002    000004    000005    000006    000007  \
# 0    20210104 -0.015160 -0.008873 -0.003585 -0.010165 -0.012514       NaN
# 1    20210105  0.011209  0.005584 -0.010914 -0.010923 -0.005763       NaN
# 2    20210106  0.020182  0.007172 -0.016159 -0.007238 -0.007331 -0.027498
# 3    20210107  0.002479  0.001442 -0.008702 -0.003402 -0.006117       NaN
# 4    20210108  0.007354  0.008051 -0.006289 -0.003402  0.000611       NaN
# ..        ...       ...       ...       ...       ...       ...       ...
# 839  20240624  0.008231  0.005463 -0.009059       NaN  0.014266       NaN
# 840  20240625  0.000699  0.004620 -0.003971       NaN  0.002621       NaN
# 841  20240626  0.002224 -0.000587  0.029589       NaN -0.001290       NaN
# 842  20240627  0.004883 -0.004139  0.046863       NaN  0.008384       NaN
# 843  20240628  0.001902  0.006736  0.003809       NaN  0.004952       NaN
#
#        000008    000009    000010  ...  301585  301598  603194  001391  \
# ...
